# %% [markdown]
# <a href="https://colab.research.google.com/github/saransh2396/Cardiovascular-Risk-Prediction/blob/main/Dec_12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Mounting drive to load data 
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Importing the libraries
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Data Description

# %%
#Loading the data
df = pd.read_csv('/content/drive/MyDrive/Cardiovascular Risk Prediction - Saransh Srivastava/data_cardiovascular_risk.csv',encoding= 'unicode_escape')
df.head()
# Out:
#    id  age  education sex  ...    BMI  heartRate  glucose  TenYearCHD
# 0   0   64        2.0   F  ...    NaN       90.0     80.0           1
# 1   1   36        4.0   M  ...  29.77       72.0     75.0           0
# 2   2   46        1.0   F  ...  20.35       88.0     94.0           0
# 3   3   50        1.0   M  ...  28.26       68.0     94.0           1
# 4   4   64        1.0   F  ...  26.42       70.0     77.0           0
#
# [5 rows x 17 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3390 entries, 0 to 3389
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               3390 non-null   int64
#  1   age              3390 non-null   int64
#  2   education        3303 non-null   float64
#  3   sex              3390 non-null   object
#  4   is_smoking       3390 non-null   object
#  5   cigsPerDay       3368 non-null   float64
#  6   BPMeds           3346 non-null   float64
#  7   prevalentStroke  3390 non-null   int64
#  8   prevalentHyp     3390 non-null   int64
#  9   diabetes         3390 non-null   int64
#  10  totChol          3352 non-null   float64
#  11  sysBP            3390 non-null   float64
#  12  diaBP            3390 non-null   float64
#  13  BMI              3376 non-null   float64
#  14  heartRate        3389 non-null   float64
#  15  glucose          3086 non-null   float64
#  16  TenYearCHD       3390 non-null   int64
# dtypes: float64(9), int64(6), object(2)
# memory usage: 450.4+ KB

# %%
df.shape
# Out:
# (3390, 17)

# %% [markdown]
# # Handling null values

# %%
(df.isnull().sum()/len(df))*100
# Out:
# id                 0.000000
# age                0.000000
# education          2.566372
# sex                0.000000
# is_smoking         0.000000
# cigsPerDay         0.648968
# BPMeds             1.297935
# prevalentStroke    0.000000
# prevalentHyp       0.000000
# diabetes           0.000000
# totChol            1.120944
# sysBP              0.000000
# diaBP              0.000000
# BMI                0.412979
# heartRate          0.029499
# glucose            8.967552
# TenYearCHD         0.000000
# dtype: float64

# %% [markdown]
# Filling the rows which has higher than 5% null and lower than 30% null values

# %%
df['glucose'].fillna(value=df['glucose'].mode()[0],inplace=True)

# %% [markdown]
# Dropping the rows which has lower than 5% null values

# %%
df.dropna(axis=0,inplace=True)

# %%
(df.isnull().sum()/len(df))*100
# Out:
# id                 0.0
# age                0.0
# education          0.0
# sex                0.0
# is_smoking         0.0
# cigsPerDay         0.0
# BPMeds             0.0
# prevalentStroke    0.0
# prevalentHyp       0.0
# diabetes           0.0
# totChol            0.0
# sysBP              0.0
# diaBP              0.0
# BMI                0.0
# heartRate          0.0
# glucose            0.0
# TenYearCHD         0.0
# dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3189 entries, 1 to 3389
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               3189 non-null   int64
#  1   age              3189 non-null   int64
#  2   education        3189 non-null   float64
#  3   sex              3189 non-null   object
#  4   is_smoking       3189 non-null   object
#  5   cigsPerDay       3189 non-null   float64
#  6   BPMeds           3189 non-null   float64
#  7   prevalentStroke  3189 non-null   int64
#  8   prevalentHyp     3189 non-null   int64
#  9   diabetes         3189 non-null   int64
#  10  totChol          3189 non-null   float64
#  11  sysBP            3189 non-null   float64
#  12  diaBP            3189 non-null   float64
#  13  BMI              3189 non-null   float64
#  14  heartRate        3189 non-null   float64
#  15  glucose          3189 non-null   float64
#  16  TenYearCHD       3189 non-null   int64
# dtypes: float64(9), int64(6), object(2)
# memory usage: 448.5+ KB

# %%
#Dropping id column
df.drop(['id'],axis=1,inplace=True)

# %%
df.describe()
# Out:
#                age    education  ...      glucose   TenYearCHD
# count  3189.000000  3189.000000  ...  3189.000000  3189.000000
# mean     49.423957     1.972719  ...    81.364691     0.148950
# std       8.556235     1.018435  ...    23.173510     0.356095
# min      32.000000     1.000000  ...    40.000000     0.000000
# 25%      42.000000     1.000000  ...    72.000000     0.000000
# 50%      49.000000     2.000000  ...    77.000000     0.000000
# 75%      56.000000     3.000000  ...    85.000000     0.000000
# max      70.000000     4.000000  ...   394.000000     1.000000
#
# [8 rows x 14 columns]

# %%
df.shape
# Out:
# (3189, 16)

# %%
df.head()
# Out:
#    age  education sex is_smoking  ...    BMI  heartRate  glucose  TenYearCHD
# 1   36        4.0   M         NO  ...  29.77       72.0     75.0           0
# 2   46        1.0   F        YES  ...  20.35       88.0     94.0           0
# 3   50        1.0   M        YES  ...  28.26       68.0     94.0           1
# 4   64        1.0   F        YES  ...  26.42       70.0     77.0           0
# 5   61        3.0   F         NO  ...  32.80       85.0     65.0           1
#
# [5 rows x 16 columns]

# %%
df.tail()
# Out:
#       age  education sex is_smoking  ...    BMI  heartRate  glucose  TenYearCHD
# 3384   61        1.0   F         NO  ...  26.98      105.0    113.0           0
# 3385   60        1.0   F         NO  ...  29.28       70.0    103.0           0
# 3386   46        1.0   F         NO  ...  21.96       80.0     84.0           0
# 3387   44        3.0   M        YES  ...  28.92       73.0     72.0           1
# 3389   54        3.0   F         NO  ...  29.88       79.0     92.0           0
#
# [5 rows x 16 columns]

# %% [markdown]
# ###Target Variable

# %%
df['TenYearCHD'].value_counts()
# Out:
# 0    2714
# 1     475
# Name: TenYearCHD, dtype: int64

# %% [markdown]
# TenYearCHD is the target variable

# %% [markdown]
# # EDA

# %%
#Storing all the features which has continuous values
continuous_variables = ['age','cigsPerDay','totChol','sysBP','diaBP','BMI','heartRate','glucose']

# %%
other_variables = ['education','sex','is_smoking','prevalentStroke','prevalentHyp','diabetes']

# %%
#Analyzing the distribution of all the features which has continuous values
for col in continuous_variables:
  sns.displot(df[col])
plt.show()

# %%
#Counting all the encoded values where dependent variable is the parameter
for col in other_variables:
  sns.countplot(x=df[col],hue=df['TenYearCHD'],data=df)
  plt.show()

# %%
#sysBP varying amomng the genders
sns.barplot(x=df['sex'],y=df['sysBP'],data=df)

# %%
#diaBP varying among the genders
sns.barplot(x=df['sex'],y=df['diaBP'],data=df)

# %%
#total Cholestrol varying among the genders
sns.barplot(x=df['sex'],y=df['totChol'],data=df)

# %%
#total cholestrol of a person who is at risk and who isn't
sns.barplot(x=df['TenYearCHD'],y=df['totChol'],data=df)

# %%
#sysBP of a person who is at risk and who isn't
sns.barplot(x=df['TenYearCHD'],y=df['sysBP'],data=df)

# %%
#diaBP of a person who is at risk and who isn't
sns.barplot(x=df['TenYearCHD'],y=df['diaBP'],data=df)

# %%
#Finding When a person gets old how much their glucose level varies
plt.figure(figsize=(10,6))
sns.lineplot(x=df['age'],y=df['glucose'],hue=df['sex'],data=df)

# %%
#Finding when a person gets old how much Cholestrol level varies
plt.figure(figsize=(10,6))
sns.lineplot(x=df['age'],y=df['totChol'],hue=df['sex'],data=df)

# %%
#Finding when a person gets old how much their BMI level varies
plt.figure(figsize=(10,6))
sns.lineplot(x=df['age'],y=df['BMI'],hue=df['sex'],data=df)

# %%
#Finding when a person gets old how much their heart rate level varies
plt.figure(figsize=(10,6))
sns.lineplot(x=df['age'],y=df['heartRate'],hue=df['sex'],data=df)

# %%
#Finding when a person gets old how much their diaBP level varies
plt.figure(figsize=(10,6))
sns.lineplot(x=df['age'],y=df['diaBP'],hue=df['sex'],data=df)

# %%
#Finding when a person gets old how much their sysBP level varies
plt.figure(figsize=(10,6))
sns.lineplot(x=df['age'],y=df['sysBP'],hue=df['sex'],data=df)

# %% [markdown]
# # Handling Outliers

# %%
#Box Plot for analyzing the outliers
df.plot(kind='box',figsize=(16,8))

# %%
#Stored all the features where we want to remove outliers
outlier_col = ['cigsPerDay','totChol','sysBP','diaBP','BMI','heartRate','glucose']

# %%
#Analyzing the outlier columns
for col in outlier_col:
  sns.boxplot(x=df['TenYearCHD'],y=df[col],data=df)
  plt.show()

# %%
#Handling Outliers
df[outlier_col]=df[outlier_col].clip(lower=df[outlier_col].quantile(0.15),upper=df[outlier_col].quantile(0.85),axis=1)

# %%
#Box plot after handling outliers
df.plot(kind='box',figsize=(16,8))

# %%
for col in outlier_col:
  sns.boxplot(x=df['TenYearCHD'],y=df[col],data=df)
  plt.show()

# %% [markdown]
# # Multicollinearity

# %%
# Heatmap:
plt.figure(figsize=(14,8))
sns.heatmap(df.corr(),annot=True)

# %%
# Multicollinearity
from statsmodels.stats.outliers_influence import variance_inflation_factor
def calc_vif(X):
 
   # Calculating VIF
   vif = pd.DataFrame()
   vif["variables"] = X.columns
   vif["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
 
   return(vif)
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
calc_vif(df[[i for i in df.describe().columns ]])
# Out:
#           variables         VIF
# 0               age   47.044314
# 1         education    4.796363
# 2        cigsPerDay    1.839989
# 3            BPMeds    1.130465
# 4   prevalentStroke    1.028448
# 5      prevalentHyp    2.555430
# 6          diabetes    1.070168
# 7           totChol   62.811486
# 8             sysBP  265.055672
# 9             diaBP  250.502661
# 10              BMI   95.457184
# 11        heartRate   77.148617
# 12          glucose   81.075642
# 13       TenYearCHD    1.276424

# %% [markdown]
# sysBp means systolic blood pressure and diaBP means diastolic blood pressure are correalted to eaach other but we cannot drop these columns as
# Blood pressure is measured using two numbers: The first number, called systolic blood pressure, measures the pressure in your arteries when your heart beats. The second number, called diastolic blood pressure, measures the pressure in your arteries when your heart rests between beats.

# %% [markdown]
# # Label Encoding

# %%
#Mapping the Variables
df['is_smoking']=df['is_smoking'].map({'YES':1,'NO':0})
df['sex']=df['sex'].map({'M':0,'F':1})

# %%
df.head(2)
# Out:
#    age  education  sex  is_smoking  ...     BMI  heartRate  glucose  TenYearCHD
# 1   36        4.0    0           0  ...  29.576       72.0     75.0           0
# 2   46        1.0    1           1  ...  21.800       88.0     92.0           0
#
# [2 rows x 16 columns]

# %% [markdown]
# # Feature Selection

# %%
X = df.iloc[:,0:-1].values
y=df['TenYearCHD'].values

# %%
X
# Out:
# array([[36.   ,  4.   ,  0.   , ..., 29.576, 72.   , 75.   ],
#        [46.   ,  1.   ,  1.   , ..., 21.8  , 88.   , 92.   ],
#        [50.   ,  1.   ,  0.   , ..., 28.26 , 68.   , 92.   ],
#        ...,
#        [46.   ,  1.   ,  1.   , ..., 21.96 , 80.   , 84.   ],
#        [44.   ,  3.   ,  0.   , ..., 28.92 , 73.   , 72.   ],
#        [54.   ,  3.   ,  1.   , ..., 29.576, 79.   , 92.   ]])

# %%
y
# Out:
# array([0, 0, 1, ..., 0, 1, 0])

# %%
X.shape,y.shape
# Out:
# ((3189, 15), (3189,))

# %% [markdown]
# # Splitting & Scaling data

# %%
#Splitting the data into training and testing dataset
X_train, X_test, y_train, y_test = train_test_split( X,y , test_size = 0.2, random_state = 0)

# %%
#Checking the shape of our training and testing datasets
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (2551, 15)
# (638, 15)
# (2551,)
# (638,)

# %%
#Using Standard Scaler to scale 
from sklearn.preprocessing import StandardScaler 
scaler = StandardScaler() 
X_train = scaler.fit_transform(X_train) 
X_test = scaler.transform(X_test)

# %% [markdown]
# # Implementing Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
Log = LogisticRegression()

# %%
#Fitting the training datasets
Log.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
#predicting on training dataset
y_pred_log_train = Log.predict(X_train)

# %%
#predicting on testing dataset
y_pred_log_test = Log.predict(X_test)

# %% [markdown]
# ## Classification Evaluation Metrics on Logistic Regression.

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
#Accuracy score of training
log_acc_train = accuracy_score(y_train,y_pred_log_train)*100
log_acc_train
# Out:
# 85.57428459427675

# %%
#Accuracy score of testing
log_acc_test = accuracy_score(y_test,y_pred_log_test)*100
log_acc_test
# Out:
# 85.57993730407524

# %%
#Confusion Metrics of training
cm_log_train = confusion_matrix(y_train,y_pred_log_train)
cm_log_train
# Out:
# array([[2166,   10],
#        [ 358,   17]])

# %%
#Confusion Metrics of testing
cm_log_test = confusion_matrix(y_test,y_pred_log_test)
cm_log_test
# Out:
# array([[534,   4],
#        [ 88,  12]])

# %%
#Classification Report of training
print(classification_report(y_train,y_pred_log_train))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92      2176
#            1       0.63      0.05      0.08       375
#
#     accuracy                           0.86      2551
#    macro avg       0.74      0.52      0.50      2551
# weighted avg       0.82      0.86      0.80      2551

# %%
#Classification report of testing
print(classification_report(y_test,y_pred_log_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.99      0.92       538
#            1       0.75      0.12      0.21       100
#
#     accuracy                           0.86       638
#    macro avg       0.80      0.56      0.56       638
# weighted avg       0.84      0.86      0.81       638

# %% [markdown]
# AS our data is highly imbalance so we have to improve this

# %% [markdown]
# # Using Smotek Technique

# %%
from imblearn.combine import SMOTETomek
from imblearn.under_sampling import NearMiss

# %%
# Implementing Oversampling for Handling Imbalanced 
smk = SMOTETomek(random_state=42)
X_res,y_res=smk.fit_resample(X,y)

# %%
X_res.shape,y_res.shape,X.shape,y.shape
# Out:
# ((5380, 15), (5380,), (3189, 15), (3189,))

# %% [markdown]
# ##Splitting & scaling data after Smotek Technique

# %%
#Splitting the data
X_train_res, X_test_res, y_train_res, y_test_res = train_test_split(X_res, y_res, test_size = 0.20, random_state=0)

# %%
X_train_res.shape,y_train_res.shape
# Out:
# ((4304, 15), (4304,))

# %%
#Scaling the data
X_train_res = scaler.fit_transform(X_train_res)
X_test_res = scaler.fit_transform(X_test_res)

# %%
X_train_res.shape,y_train_res.shape
# Out:
# ((4304, 15), (4304,))

# %% [markdown]
# # Implementing Logistic Regression after using Smotek Technique

# %%
model_smotek = LogisticRegression()

# %%
model_smotek.fit(X_train_res,y_train_res)
# Out:
# LogisticRegression()

# %% [markdown]
# ## Classification Evaluation Metrics on Logistic Regression after using Logistic Regression

# %%
y_pred_smotek_train = model_smotek.predict(X_train_res)

# %%
y_pred_smotek_test = model_smotek.predict(X_test_res)

# %%
#Accuaracy score of training
log_acc_train = accuracy_score(y_train_res,y_pred_smotek_train)*100
log_acc_train
# Out:
# 66.82156133828995

# %%
#Confusion Matrix of training
confusion_matrix(y_train_res,y_pred_smotek_train)
# Out:
# array([[1418,  730],
#        [ 698, 1458]])

# %%
#Classification report of training
print(classification_report(y_train_res,y_pred_smotek_train))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.67      0.66      0.67      2148
#            1       0.67      0.68      0.67      2156
#
#     accuracy                           0.67      4304
#    macro avg       0.67      0.67      0.67      4304
# weighted avg       0.67      0.67      0.67      4304

# %%
#Accuaracy score of testing
log_acc_test = accuracy_score(y_test_res,y_pred_smotek_test)*100
log_acc_test
# Out:
# 67.4721189591078

# %%
#Confusion Matrix of testing
confusion_matrix(y_test_res,y_pred_smotek_test)
# Out:
# array([[361, 181],
#        [169, 365]])

# %%
#Classification report of testing
print(classification_report(y_test_res,y_pred_smotek_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.68      0.67      0.67       542
#            1       0.67      0.68      0.68       534
#
#     accuracy                           0.67      1076
#    macro avg       0.67      0.67      0.67      1076
# weighted avg       0.67      0.67      0.67      1076

# %% [markdown]
# #Implementing Random Forest Classifier

# %%
from sklearn.ensemble import  RandomForestClassifier

# %%
rfc = RandomForestClassifier(max_depth=2, random_state=0)
#Fitting Random Forest Classifier on training dataset
rfc.fit(X_train_res, y_train_res)
# Out:
# RandomForestClassifier(max_depth=2, random_state=0)

# %%
#predicting on training & testing datasets
rfc_pred_train = rfc.predict(X_train_res)
rfc_pred_test = rfc.predict(X_test_res)

# %% [markdown]
# ## Classification Evaluation Metrics on Random Forest Classifier

# %%
#Accuracy score, confusion matrix and classification report of training 
rfc_acc_train = accuracy_score(y_train_res,rfc_pred_train)*100
print(rfc_acc_train)
print(confusion_matrix(y_train_res,rfc_pred_train))
print(classification_report(y_train_res,rfc_pred_train))
# Out:
# 73.3039033457249
# [[1498  650]
#  [ 499 1657]]
#               precision    recall  f1-score   support
#
#            0       0.75      0.70      0.72      2148
#            1       0.72      0.77      0.74      2156
#
#     accuracy                           0.73      4304
#    macro avg       0.73      0.73      0.73      4304
# weighted avg       0.73      0.73      0.73      4304

# %%
#Accuracy score, confusion matrix and classification report of testing
rfc_acc_test = accuracy_score(y_test_res,rfc_pred_test)*100
print(rfc_acc_test)
print(confusion_matrix(y_test_res,rfc_pred_test))
print(classification_report(y_test_res,rfc_pred_test))
# Out:
# 50.0
# [[  4 538]
#  [  0 534]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.01      0.01       542
#            1       0.50      1.00      0.67       534
#
#     accuracy                           0.50      1076
#    macro avg       0.75      0.50      0.34      1076
# weighted avg       0.75      0.50      0.34      1076

# %% [markdown]
# # Implementing Support Vector Machine

# %%
from sklearn.svm import SVC

# %%
svc = SVC(C=100,gamma=0.001,kernel='rbf')

# %%
#Fitting SVM on training dataset
svc.fit(X_train_res,y_train_res)
# Out:
# SVC(C=100, gamma=0.001)

# %%
#predicting on training dataset
y_pred_train_svm = svc.predict(X_train_res)

# %%
#predicting on testing dataset
y_pred_test_svm = svc.predict(X_test_res)

# %% [markdown]
# ## Classification Evaluation Metrics on SVM.

# %%
#Accuracy score, confusion matrix and classification report of training 
acc = accuracy_score(y_pred_train_svm,y_train_res)*100
print(acc)
cmm = confusion_matrix(y_pred_train_svm,y_train_res)
print(cmm)
crr = classification_report(y_pred_train_svm,y_train_res)
print(crr)
# Out:
# 71.11988847583643
# [[1496  591]
#  [ 652 1565]]
#               precision    recall  f1-score   support
#
#            0       0.70      0.72      0.71      2087
#            1       0.73      0.71      0.72      2217
#
#     accuracy                           0.71      4304
#    macro avg       0.71      0.71      0.71      4304
# weighted avg       0.71      0.71      0.71      4304

# %%
acc_svm_test = accuracy_score(y_pred_test_svm,y_test_res)*100
print(acc_svm_test)
print(confusion_matrix(y_pred_test_svm,y_test_res))
print(classification_report(y_pred_test_svm,y_test_res))
# Out:
# 72.21189591078067
# [[383 140]
#  [159 394]]
#               precision    recall  f1-score   support
#
#            0       0.71      0.73      0.72       523
#            1       0.74      0.71      0.72       553
#
#     accuracy                           0.72      1076
#    macro avg       0.72      0.72      0.72      1076
# weighted avg       0.72      0.72      0.72      1076

# %% [markdown]
# # Hyperparameter tuning using GridSearchCV on SVM

# %%
from sklearn.model_selection import GridSearchCV

# %%
#Making a parameters dict where all parameters is of SVM
param_grid={'C':[0.1,1,10,100,1000],'gamma':[1,0.1,0.001,0.0001],'kernel':['rbf']}

# %%
grid = GridSearchCV(SVC(),param_grid,refit=True,verbose=10)

# %%
#Fitting on training dataset
grid.fit(X_train_res,y_train_res)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# [CV 1/5; 1/20] START C=0.1, gamma=1, kernel=rbf.................................
# [CV 1/5; 1/20] END ..C=0.1, gamma=1, kernel=rbf;, score=0.534 total time=   1.0s
# [CV 2/5; 1/20] START C=0.1, gamma=1, kernel=rbf.................................
# [CV 2/5; 1/20] END ..C=0.1, gamma=1, kernel=rbf;, score=0.521 total time=   1.0s
# [CV 3/5; 1/20] START C=0.1, gamma=1, kernel=rbf.................................
# [CV 3/5; 1/20] END ..C=0.1, gamma=1, kernel=rbf;, score=0.510 total time=   1.0s
# [CV 4/5; 1/20] START C=0.1, gamma=1, kernel=rbf.................................
# [CV 4/5; 1/20] END ..C=0.1, gamma=1, kernel=rbf;, score=0.561 total time=   1.0s
# [CV 5/5; 1/20] START C=0.1, gamma=1, kernel=rbf.................................
# [CV 5/5; 1/20] END ..C=0.1, gamma=1, kernel=rbf;, score=0.507 total time=   1.0s
# [CV 1/5; 2/20] START C=0.1, gamma=0.1, kernel=rbf...............................
# [CV 1/5; 2/20] END C=0.1, gamma=0.1, kernel=rbf;, score=0.706 total time=   0.9s
# [CV 2/5; 2/20] START C=0.1, gamma=0.1, kernel=rbf...............................
# [CV 2/5; 2/20] END C=0.1, gamma=0.1, kernel=rbf;, score=0.703 total time=   0.9s
# [CV 3/5; 2/20] START C=0.1, gamma=0.1, kernel=rbf...............................
# [CV 3/5; 2/20] END C=0.1, gamma=0.1, kernel=rbf;, score=0.679 total time=   0.9s
# [CV 4/5; 2/20] START C=0.1, gamma=0.1, kernel=rbf...............................
# [CV 4/5; 2/20] END C=0.1, gamma=0.1, kernel=rbf;, score=0.711 total time=   0.9s
# [CV 5/5; 2/20] START C=0.1, gamma=0.1, kernel=rbf...............................
# [CV 5/5; 2/20] END C=0.1, gamma=0.1, kernel=rbf;, score=0.709 total time=   0.9s
# [CV 1/5; 3/20] START C=0.1, gamma=0.001, kernel=rbf.............................
# [CV 1/5; 3/20] END C=0.1, gamma=0.001, kernel=rbf;, score=0.647 total time=   1.0s
# [CV 2/5; 3/20] START C=0.1, gamma=0.001, kernel=rbf.............................
# [CV 2/5; 3/20] END C=0.1, gamma=0.001, kernel=rbf;, score=0.645 total time=   1.0s
# [CV 3/5; 3/20] START C=0.1, gamma=0.001, kernel=rbf.............................
# [CV 3/5; 3/20] END C=0.1, gamma=0.001, kernel=rbf;, score=0.612 total time=   1.0s
# [CV 4/5; 3/20] START C=0.1, gamma=0.001, kernel=rbf.............................
# [CV 4/5; 3/20] END C=0.1, gamma=0.001, kernel=rbf;, score=0.652 total time=   1.0s
# [CV 5/5; 3/20] START C=0.1, gamma=0.001, kernel=rbf.............................
# [CV 5/5; 3/20] END C=0.1, gamma=0.001, kernel=rbf;, score=0.640 total time=   1.0s
# [CV 1/5; 4/20] START C=0.1, gamma=0.0001, kernel=rbf............................
# [CV 1/5; 4/20] END C=0.1, gamma=0.0001, kernel=rbf;, score=0.501 total time=   1.0s
# [CV 2/5; 4/20] START C=0.1, gamma=0.0001, kernel=rbf............................
# [CV 2/5; 4/20] END C=0.1, gamma=0.0001, kernel=rbf;, score=0.501 total time=   1.0s
# [CV 3/5; 4/20] START C=0.1, gamma=0.0001, kernel=rbf............................
# [CV 3/5; 4/20] END C=0.1, gamma=0.0001, kernel=rbf;, score=0.501 total time=   1.0s
# [CV 4/5; 4/20] START C=0.1, gamma=0.0001, kernel=rbf............................
# [CV 4/5; 4/20] END C=0.1, gamma=0.0001, kernel=rbf;, score=0.502 total time=   1.0s
# [CV 5/5; 4/20] START C=0.1, gamma=0.0001, kernel=rbf............................
# [CV 5/5; 4/20] END C=0.1, gamma=0.0001, kernel=rbf;, score=0.501 total time=   1.0s
# [CV 1/5; 5/20] START C=1, gamma=1, kernel=rbf...................................
# [CV 1/5; 5/20] END ....C=1, gamma=1, kernel=rbf;, score=0.890 total time=   1.2s
# [CV 2/5; 5/20] START C=1, gamma=1, kernel=rbf...................................
# [CV 2/5; 5/20] END ....C=1, gamma=1, kernel=rbf;, score=0.915 total time=   1.1s
# [CV 3/5; 5/20] START C=1, gamma=1, kernel=rbf...................................
# [CV 3/5; 5/20] END ....C=1, gamma=1, kernel=rbf;, score=0.883 total time=   1.1s
# [CV 4/5; 5/20] START C=1, gamma=1, kernel=rbf...................................
# [CV 4/5; 5/20] END ....C=1, gamma=1, kernel=rbf;, score=0.892 total time=   1.2s
# [CV 5/5; 5/20] START C=1, gamma=1, kernel=rbf...................................
# [CV 5/5; 5/20] END ....C=1, gamma=1, kernel=rbf;, score=0.912 total time=   1.1s
# [CV 1/5; 6/20] START C=1, gamma=0.1, kernel=rbf.................................
# [CV 1/5; 6/20] END ..C=1, gamma=0.1, kernel=rbf;, score=0.770 total time=   0.8s
# [CV 2/5; 6/20] START C=1, gamma=0.1, kernel=rbf.................................
# [CV 2/5; 6/20] END ..C=1, gamma=0.1, kernel=rbf;, score=0.812 total time=   0.8s
# [CV 3/5; 6/20] START C=1, gamma=0.1, kernel=rbf.................................
# [CV 3/5; 6/20] END ..C=1, gamma=0.1, kernel=rbf;, score=0.790 total time=   0.8s
# [CV 4/5; 6/20] START C=1, gamma=0.1, kernel=rbf.................................
# [CV 4/5; 6/20] END ..C=1, gamma=0.1, kernel=rbf;, score=0.783 total time=   0.8s
# [CV 5/5; 6/20] START C=1, gamma=0.1, kernel=rbf.................................
# [CV 5/5; 6/20] END ..C=1, gamma=0.1, kernel=rbf;, score=0.812 total time=   0.8s
# [CV 1/5; 7/20] START C=1, gamma=0.001, kernel=rbf...............................
# [CV 1/5; 7/20] END C=1, gamma=0.001, kernel=rbf;, score=0.679 total time=   0.9s
# [CV 2/5; 7/20] START C=1, gamma=0.001, kernel=rbf...............................
# [CV 2/5; 7/20] END C=1, gamma=0.001, kernel=rbf;, score=0.682 total time=   0.9s
# [CV 3/5; 7/20] START C=1, gamma=0.001, kernel=rbf...............................
# [CV 3/5; 7/20] END C=1, gamma=0.001, kernel=rbf;, score=0.649 total time=   0.9s
# [CV 4/5; 7/20] START C=1, gamma=0.001, kernel=rbf...............................
# [CV 4/5; 7/20] END C=1, gamma=0.001, kernel=rbf;, score=0.671 total time=   0.9s
# [CV 5/5; 7/20] START C=1, gamma=0.001, kernel=rbf...............................
# [CV 5/5; 7/20] END C=1, gamma=0.001, kernel=rbf;, score=0.669 total time=   0.9s
# [CV 1/5; 8/20] START C=1, gamma=0.0001, kernel=rbf..............................
# [CV 1/5; 8/20] END C=1, gamma=0.0001, kernel=rbf;, score=0.647 total time=   1.0s
# [CV 2/5; 8/20] START C=1, gamma=0.0001, kernel=rbf..............................
# [CV 2/5; 8/20] END C=1, gamma=0.0001, kernel=rbf;, score=0.647 total time=   1.0s
# [CV 3/5; 8/20] START C=1, gamma=0.0001, kernel=rbf..............................
# [CV 3/5; 8/20] END C=1, gamma=0.0001, kernel=rbf;, score=0.612 total time=   1.0s
# [CV 4/5; 8/20] START C=1, gamma=0.0001, kernel=rbf..............................
# [CV 4/5; 8/20] END C=1, gamma=0.0001, kernel=rbf;, score=0.650 total time=   1.0s
# [CV 5/5; 8/20] START C=1, gamma=0.0001, kernel=rbf..............................
# [CV 5/5; 8/20] END C=1, gamma=0.0001, kernel=rbf;, score=0.641 total time=   1.0s
# [CV 1/5; 9/20] START C=10, gamma=1, kernel=rbf..................................
# [CV 1/5; 9/20] END ...C=10, gamma=1, kernel=rbf;, score=0.900 total time=   1.1s
# [CV 2/5; 9/20] START C=10, gamma=1, kernel=rbf..................................
# [CV 2/5; 9/20] END ...C=10, gamma=1, kernel=rbf;, score=0.923 total time=   1.2s
# [CV 3/5; 9/20] START C=10, gamma=1, kernel=rbf..................................
# [CV 3/5; 9/20] END ...C=10, gamma=1, kernel=rbf;, score=0.894 total time=   1.2s
# [CV 4/5; 9/20] START C=10, gamma=1, kernel=rbf..................................
# [CV 4/5; 9/20] END ...C=10, gamma=1, kernel=rbf;, score=0.901 total time=   1.1s
# [CV 5/5; 9/20] START C=10, gamma=1, kernel=rbf..................................
# [CV 5/5; 9/20] END ...C=10, gamma=1, kernel=rbf;, score=0.917 total time=   1.2s
# [CV 1/5; 10/20] START C=10, gamma=0.1, kernel=rbf...............................
# [CV 1/5; 10/20] END C=10, gamma=0.1, kernel=rbf;, score=0.848 total time=   0.8s
# [CV 2/5; 10/20] START C=10, gamma=0.1, kernel=rbf...............................
# [CV 2/5; 10/20] END C=10, gamma=0.1, kernel=rbf;, score=0.892 total time=   0.8s
# [CV 3/5; 10/20] START C=10, gamma=0.1, kernel=rbf...............................
# [CV 3/5; 10/20] END C=10, gamma=0.1, kernel=rbf;, score=0.851 total time=   0.8s
# [CV 4/5; 10/20] START C=10, gamma=0.1, kernel=rbf...............................
# [CV 4/5; 10/20] END C=10, gamma=0.1, kernel=rbf;, score=0.849 total time=   0.8s
# [CV 5/5; 10/20] START C=10, gamma=0.1, kernel=rbf...............................
# [CV 5/5; 10/20] END C=10, gamma=0.1, kernel=rbf;, score=0.880 total time=   0.8s
# [CV 1/5; 11/20] START C=10, gamma=0.001, kernel=rbf.............................
# [CV 1/5; 11/20] END C=10, gamma=0.001, kernel=rbf;, score=0.675 total time=   0.8s
# [CV 2/5; 11/20] START C=10, gamma=0.001, kernel=rbf.............................
# [CV 2/5; 11/20] END C=10, gamma=0.001, kernel=rbf;, score=0.684 total time=   0.8s
# [CV 3/5; 11/20] START C=10, gamma=0.001, kernel=rbf.............................
# [CV 3/5; 11/20] END C=10, gamma=0.001, kernel=rbf;, score=0.657 total time=   0.8s
# [CV 4/5; 11/20] START C=10, gamma=0.001, kernel=rbf.............................
# [CV 4/5; 11/20] END C=10, gamma=0.001, kernel=rbf;, score=0.685 total time=   0.8s
# [CV 5/5; 11/20] START C=10, gamma=0.001, kernel=rbf.............................
# [CV 5/5; 11/20] END C=10, gamma=0.001, kernel=rbf;, score=0.683 total time=   0.8s
# [CV 1/5; 12/20] START C=10, gamma=0.0001, kernel=rbf............................
# [CV 1/5; 12/20] END C=10, gamma=0.0001, kernel=rbf;, score=0.679 total time=   0.9s
# [CV 2/5; 12/20] START C=10, gamma=0.0001, kernel=rbf............................
# [CV 2/5; 12/20] END C=10, gamma=0.0001, kernel=rbf;, score=0.677 total time=   0.9s
# [CV 3/5; 12/20] START C=10, gamma=0.0001, kernel=rbf............................
# [CV 3/5; 12/20] END C=10, gamma=0.0001, kernel=rbf;, score=0.648 total time=   0.9s
# [CV 4/5; 12/20] START C=10, gamma=0.0001, kernel=rbf............................
# [CV 4/5; 12/20] END C=10, gamma=0.0001, kernel=rbf;, score=0.671 total time=   0.9s
# [CV 5/5; 12/20] START C=10, gamma=0.0001, kernel=rbf............................
# [CV 5/5; 12/20] END C=10, gamma=0.0001, kernel=rbf;, score=0.665 total time=   0.9s
# [CV 1/5; 13/20] START C=100, gamma=1, kernel=rbf................................
# [CV 1/5; 13/20] END .C=100, gamma=1, kernel=rbf;, score=0.899 total time=   1.2s
# [CV 2/5; 13/20] START C=100, gamma=1, kernel=rbf................................
# [CV 2/5; 13/20] END .C=100, gamma=1, kernel=rbf;, score=0.923 total time=   1.2s
# [CV 3/5; 13/20] START C=100, gamma=1, kernel=rbf................................
# [CV 3/5; 13/20] END .C=100, gamma=1, kernel=rbf;, score=0.893 total time=   1.2s
# [CV 4/5; 13/20] START C=100, gamma=1, kernel=rbf................................
# [CV 4/5; 13/20] END .C=100, gamma=1, kernel=rbf;, score=0.901 total time=   1.2s
# [CV 5/5; 13/20] START C=100, gamma=1, kernel=rbf................................
# [CV 5/5; 13/20] END .C=100, gamma=1, kernel=rbf;, score=0.917 total time=   1.1s
# [CV 1/5; 14/20] START C=100, gamma=0.1, kernel=rbf..............................
# [CV 1/5; 14/20] END C=100, gamma=0.1, kernel=rbf;, score=0.848 total time=   1.1s
# [CV 2/5; 14/20] START C=100, gamma=0.1, kernel=rbf..............................
# [CV 2/5; 14/20] END C=100, gamma=0.1, kernel=rbf;, score=0.895 total time=   1.1s
# [CV 3/5; 14/20] START C=100, gamma=0.1, kernel=rbf..............................
# [CV 3/5; 14/20] END C=100, gamma=0.1, kernel=rbf;, score=0.864 total time=   1.1s
# [CV 4/5; 14/20] START C=100, gamma=0.1, kernel=rbf..............................
# [CV 4/5; 14/20] END C=100, gamma=0.1, kernel=rbf;, score=0.868 total time=   1.1s
# [CV 5/5; 14/20] START C=100, gamma=0.1, kernel=rbf..............................
# [CV 5/5; 14/20] END C=100, gamma=0.1, kernel=rbf;, score=0.888 total time=   1.1s
# [CV 1/5; 15/20] START C=100, gamma=0.001, kernel=rbf............................
# [CV 1/5; 15/20] END C=100, gamma=0.001, kernel=rbf;, score=0.692 total time=   0.9s
# [CV 2/5; 15/20] START C=100, gamma=0.001, kernel=rbf............................
# [CV 2/5; 15/20] END C=100, gamma=0.001, kernel=rbf;, score=0.706 total time=   0.8s
# [CV 3/5; 15/20] START C=100, gamma=0.001, kernel=rbf............................
# [CV 3/5; 15/20] END C=100, gamma=0.001, kernel=rbf;, score=0.677 total time=   0.9s
# [CV 4/5; 15/20] START C=100, gamma=0.001, kernel=rbf............................
# [CV 4/5; 15/20] END C=100, gamma=0.001, kernel=rbf;, score=0.708 total time=   0.8s
# [CV 5/5; 15/20] START C=100, gamma=0.001, kernel=rbf............................
# [CV 5/5; 15/20] END C=100, gamma=0.001, kernel=rbf;, score=0.706 total time=   0.9s
# [CV 1/5; 16/20] START C=100, gamma=0.0001, kernel=rbf...........................
# [CV 1/5; 16/20] END C=100, gamma=0.0001, kernel=rbf;, score=0.666 total time=   0.8s
# [CV 2/5; 16/20] START C=100, gamma=0.0001, kernel=rbf...........................
# [CV 2/5; 16/20] END C=100, gamma=0.0001, kernel=rbf;, score=0.681 total time=   0.8s
# [CV 3/5; 16/20] START C=100, gamma=0.0001, kernel=rbf...........................
# [CV 3/5; 16/20] END C=100, gamma=0.0001, kernel=rbf;, score=0.655 total time=   0.8s
# [CV 4/5; 16/20] START C=100, gamma=0.0001, kernel=rbf...........................
# [CV 4/5; 16/20] END C=100, gamma=0.0001, kernel=rbf;, score=0.675 total time=   0.8s
# [CV 5/5; 16/20] START C=100, gamma=0.0001, kernel=rbf...........................
# [CV 5/5; 16/20] END C=100, gamma=0.0001, kernel=rbf;, score=0.669 total time=   0.8s
# [CV 1/5; 17/20] START C=1000, gamma=1, kernel=rbf...............................
# [CV 1/5; 17/20] END C=1000, gamma=1, kernel=rbf;, score=0.899 total time=   1.2s
# [CV 2/5; 17/20] START C=1000, gamma=1, kernel=rbf...............................
# [CV 2/5; 17/20] END C=1000, gamma=1, kernel=rbf;, score=0.923 total time=   1.2s
# [CV 3/5; 17/20] START C=1000, gamma=1, kernel=rbf...............................
# [CV 3/5; 17/20] END C=1000, gamma=1, kernel=rbf;, score=0.893 total time=   1.2s
# [CV 4/5; 17/20] START C=1000, gamma=1, kernel=rbf...............................
# [CV 4/5; 17/20] END C=1000, gamma=1, kernel=rbf;, score=0.901 total time=   1.2s
# [CV 5/5; 17/20] START C=1000, gamma=1, kernel=rbf...............................
# [CV 5/5; 17/20] END C=1000, gamma=1, kernel=rbf;, score=0.917 total time=   1.1s
# [CV 1/5; 18/20] START C=1000, gamma=0.1, kernel=rbf.............................
# [CV 1/5; 18/20] END C=1000, gamma=0.1, kernel=rbf;, score=0.842 total time=   1.3s
# [CV 2/5; 18/20] START C=1000, gamma=0.1, kernel=rbf.............................
# [CV 2/5; 18/20] END C=1000, gamma=0.1, kernel=rbf;, score=0.895 total time=   1.4s
# [CV 3/5; 18/20] START C=1000, gamma=0.1, kernel=rbf.............................
# [CV 3/5; 18/20] END C=1000, gamma=0.1, kernel=rbf;, score=0.854 total time=   1.4s
# [CV 4/5; 18/20] START C=1000, gamma=0.1, kernel=rbf.............................
# [CV 4/5; 18/20] END C=1000, gamma=0.1, kernel=rbf;, score=0.861 total time=   1.2s
# [CV 5/5; 18/20] START C=1000, gamma=0.1, kernel=rbf.............................
# [CV 5/5; 18/20] END C=1000, gamma=0.1, kernel=rbf;, score=0.872 total time=   1.4s
# [CV 1/5; 19/20] START C=1000, gamma=0.001, kernel=rbf...........................
# [CV 1/5; 19/20] END C=1000, gamma=0.001, kernel=rbf;, score=0.728 total time=   1.2s
# [CV 2/5; 19/20] START C=1000, gamma=0.001, kernel=rbf...........................
# [CV 2/5; 19/20] END C=1000, gamma=0.001, kernel=rbf;, score=0.726 total time=   1.2s
# [CV 3/5; 19/20] START C=1000, gamma=0.001, kernel=rbf...........................
# [CV 3/5; 19/20] END C=1000, gamma=0.001, kernel=rbf;, score=0.721 total time=   1.2s
# [CV 4/5; 19/20] START C=1000, gamma=0.001, kernel=rbf...........................
# [CV 4/5; 19/20] END C=1000, gamma=0.001, kernel=rbf;, score=0.747 total time=   1.2s
# [CV 5/5; 19/20] START C=1000, gamma=0.001, kernel=rbf...........................
# [CV 5/5; 19/20] END C=1000, gamma=0.001, kernel=rbf;, score=0.752 total time=   1.2s
# [CV 1/5; 20/20] START C=1000, gamma=0.0001, kernel=rbf..........................
# [CV 1/5; 20/20] END C=1000, gamma=0.0001, kernel=rbf;, score=0.669 total time=   0.9s
# [CV 2/5; 20/20] START C=1000, gamma=0.0001, kernel=rbf..........................
# [CV 2/5; 20/20] END C=1000, gamma=0.0001, kernel=rbf;, score=0.686 total time=   0.9s
# [CV 3/5; 20/20] START C=1000, gamma=0.0001, kernel=rbf..........................
# [CV 3/5; 20/20] END C=1000, gamma=0.0001, kernel=rbf;, score=0.661 total time=   0.9s
# [CV 4/5; 20/20] START C=1000, gamma=0.0001, kernel=rbf..........................
# [CV 4/5; 20/20] END C=1000, gamma=0.0001, kernel=rbf;, score=0.685 total time=   0.9s
# [CV 5/5; 20/20] START C=1000, gamma=0.0001, kernel=rbf..........................
# [CV 5/5; 20/20] END C=1000, gamma=0.0001, kernel=rbf;, score=0.681 total time=   0.9s
# GridSearchCV(estimator=SVC(),
#              param_grid={'C': [0.1, 1, 10, 100, 1000],
#                          'gamma': [1, 0.1, 0.001, 0.0001], 'kernel': ['rbf']},
#              verbose=10)

# %%
#getting the best parameters
grid.best_params_
# Out:
# {'C': 10, 'gamma': 1, 'kernel': 'rbf'}

# %%
svc_2 = SVC(C=10,gamma=1,kernel='rbf')

# %%
#Fitting on training dataset using the best parameters
svc_2.fit(X_train_res,y_train_res)
# Out:
# SVC(C=10, gamma=1)

# %%
#predicting on training and testing dataset after using the best parameters
y_pred_train_svm_grid = svc_2.predict(X_train_res)
y_pred_test_svm_grid = svc_2.predict(X_test_res)

# %% [markdown]
# ## Classification Evaluation Metrics on SVM after Hyperparameter tuning

# %%
#Accuracy score, confusion matrix and classification report of training 
acc_svm_train_grid = accuracy_score(y_pred_train_svm_grid,y_train_res)*100
print(acc_svm_train_grid)
cmm_svm_train_grid = confusion_matrix(y_pred_train_svm_grid,y_train_res)
print(cmm_svm_train_grid)
crr_svm_train_grid = classification_report(y_pred_train_svm_grid,y_train_res)
print(crr_svm_train_grid)
# Out:
# 99.97676579925651
# [[2147    0]
#  [   1 2156]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      2147
#            1       1.00      1.00      1.00      2157
#
#     accuracy                           1.00      4304
#    macro avg       1.00      1.00      1.00      4304
# weighted avg       1.00      1.00      1.00      4304

# %%
#Accuracy score, confusion matrix and classification report of testing
acc_svm_test_grid = accuracy_score(y_pred_test_svm_grid,y_test_res)*100
print(acc_svm_test_grid)
print(confusion_matrix(y_pred_test_svm_grid,y_test_res))
print(classification_report(y_pred_test_svm_grid,y_test_res))
# Out:
# 93.12267657992564
# [[517  49]
#  [ 25 485]]
#               precision    recall  f1-score   support
#
#            0       0.95      0.91      0.93       566
#            1       0.91      0.95      0.93       510
#
#     accuracy                           0.93      1076
#    macro avg       0.93      0.93      0.93      1076
# weighted avg       0.93      0.93      0.93      1076

# %% [markdown]
# Today's Work

# %% [markdown]
# # Comparision of evaluation metrics of the models being used

# %%
models = ['Logistic Regression','RFC','SVM','Tuned SVM']
acc = [log_acc_test,rfc_acc_test,acc_svm_test,acc_svm_test_grid]

sns.set_style("whitegrid")
plt.figure(figsize=(10,5))
plt.ylabel("Accuracy")
plt.xlabel("Machine Learning Model")
sns.barplot(x= models, y= acc)
plt.title('Comparision of Accuracy of Testing data among the models')
plt.show()

# %% [markdown]
# # Conclusion
